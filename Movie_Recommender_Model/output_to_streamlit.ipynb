# %%
from webscrapping import Data, get_data


def output(movie_title):
    data = get_data()
    movie_data = data.loc[data['title'] == movie_title]
    text = movie_data['text']
    duration = movie_data['duration']
    genre = movie_data['genre']
    title = movie_data['title']
    return text, duration, title

# %%
output('The Godfather')[2]
# Out:
# 1    The Godfather
# Name: title, dtype: object

# %%
get_data()
# Out:
#       Unnamed: 0                                          title  \
# 0              0                       The Shawshank Redemption
# 1              1                                  The Godfather
# 2              2                                The Dark Knight
# 3              3  The Lord of the Rings: The Return of the King
# 4              4                               Schindler's List
# ...          ...                                            ...
# 7145        7145                                Monster a Go-Go
# 7146        7146                                   Pledge This!
# 7147        7147                       Manos: The Hands of Fate
# 7148        7148                   Superbabies: Baby Geniuses 2
# 7149        7149                Kirk Cameron's Saving Christmas
#
#                           genre  duration  \
# 0                         Drama       142
# 1                  Crime, Drama       175
# 2          Action, Crime, Drama       152
# ...
