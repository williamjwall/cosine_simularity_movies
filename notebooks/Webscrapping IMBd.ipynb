# %%
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd

# %%
pages = np.arange(0, 1000, 100)
movie_list = []

# %%
for page in pages:

    URL = "https://www.imdb.com/search/title/?groups=top_1000&sort=user_rating,desc&count=100&start=" + str(page)
    response = requests.get(URL, headers={"Accept-Language":"en-US"})
    soup = BeautifulSoup(response.content, "html.parser")
    movies = soup.find_all(class_='lister-item-content')
  
    for movie in movies:
        if page < 10:
            title = movie.find("h3", class_= "lister-item-header").text[3:].replace('\n', ' ')
        if 10 <= page:
            title = movie.find("h3", class_= "lister-item-header").text[5:].replace('\n', ' ')
    
        txt = movie.find_all("p", class_= "text-muted")[1].text.lstrip('\n')
        genre = movie.find("span", class_ = 'genre').text.lstrip('\n').strip()

        movie_list.append({'title': title, 'txt': txt, 'genre': genre})

# %%
movie_df = pd.DataFrame(movie_list)

# %%
movie_df.iloc[9:103]
# Out:
#                                                  title  \
# 9                                  . Inception (2010)
# 10     . The Lord of the Rings: The Two Towers (2002)
# 11                                . Fight Club (1999)
# 12   . The Lord of the Rings: The Fellowship of the...
# 13                              . Forrest Gump (1994)
# ..                                                 ...
# 98                                 . Incendies (2010)
# 99                  0. Spider-Man: No Way Home (2021)
# 100                    Spider-Man: No Way Home (2021)
# 101                                         Up (2009)
# 102                        Like Stars on Earth (2007)
#
#                                                    txt  \
# 9    A thief who steals corporate secrets through t...
# 10   While Frodo and Sam edge closer to Mordor with...
# 11   An insomniac office worker and a devil-may-car...
# 12   A meek Hobbit from the Shire and eight compani...
# 13   The presidencies of Kennedy and Johnson, the V...
# ..                                                 ...
# 98   Twins journey to the Middle East to discover t...
# 99   With Spider-Man's identity now revealed, Peter...
# 100  With Spider-Man's identity now revealed, Peter...
# 101  78-year-old Carl Fredricksen travels to Paradi...
# 102  An eight-year-old boy is thought to be a lazy ...
#
#                             genre
# 9       Action, Adventure, Sci-Fi
# 10       Action, Adventure, Drama
# 11                          Drama
# 12       Action, Adventure, Drama
# 13                 Drama, Romance
# ..                            ...
# 98                 Drama, Mystery
# 99     Action, Adventure, Fantasy
# 100    Action, Adventure, Fantasy
# 101  Animation, Adventure, Comedy
# 102                 Drama, Family
#
# [94 rows x 3 columns]
