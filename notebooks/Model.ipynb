# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# %%
Y = X[0]

# %%
movies_df
# Out:
#       Unnamed: 0                                          title  \
# 0              0                       The Shawshank Redemption
# 1              1                                  The Godfather
# 2              2                                The Dark Knight
# 3              3  The Lord of the Rings: The Return of the King
# 4              4                               Schindler's List
# ...          ...                                            ...
# 7145        7145                                Monster a Go-Go
# 7146        7146                                   Pledge This!
# 7147        7147                       Manos: The Hands of Fate
# 7148        7148                   Superbabies: Baby Geniuses 2
# 7149        7149                Kirk Cameron's Saving Christmas
#
#                           genre  duration  \
# 0                         Drama       142
# 1                  Crime, Drama       175
# 2          Action, Crime, Drama       152
# ...

# %%
type(X[0])
# Out:
# str

# %%
X[0]
# Out:
# '  (0, 11)\t1.0\n  (1, 6)\t1.0\n  (2, 7)\t1.0\n  (3, 1)\t1.0\n  (4, 8)\t1.0\n  (5, 12)\t1.0\n  (6, 5)\t1.0\n  (7, 10)\t1.0\n  (8, 4)\t1.0\n  (9, 9)\t1.0\n  (10, 0)\t1.0\n  (11, 2)\t1.0\n  (12, 3)\t1.0'

# %%
cosine_similarity(X, Y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [42], in <cell line: 1>()
# ----> 1 cosine_similarity(X, Y)
#
# File ~/.pyenv/versions/3.8.12/envs/Movie_Recommender/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:1351, in cosine_similarity(X, Y, dense_output)
#    1317 """Compute cosine similarity between samples in X and Y.
#    1318
#    1319 Cosine similarity, or the cosine kernel, computes similarity as the
#    (...)
#    1347 kernel matrix : ndarray of shape (n_samples_X, n_samples_Y)
#    1348 """
#    1349 # to avoid recursive import
# -> 1351 X, Y = check_pairwise_arrays(X, Y)
#    1353 X_normalized = normalize(X, copy=True)
#    1354 if X is Y:
#
# File ~/.pyenv/versions/3.8.12/envs/Movie_Recommender/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:156, in check_pairwise_arrays(X, Y, precomputed, dtype, accept_sparse, force_all_finite, copy)
# ...
